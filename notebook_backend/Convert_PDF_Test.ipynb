# %%
import os
from weasyprint import HTML
# 우리가 만든 메인 통제소 함수 임포트
from nametag_pdf_builder import assemble_html

# %%
brand_info = {'brand_name': '숲결', 'brand_name_en': 'Supgyeol', 'name_meaning': '햇빛에 비친 물결처럼 반짝이는 일상의 창가', 'slogan': '마음이 쉬어가는 소품의 온도', 'story_summary': '환경을 생각하는 소비가 개인의 자부심이 되도록, 지속 가능한 소재의 아름다움을 제안합니다.', 'seed_color': '#F5E6D3', 'seed_color_reason': '리넨의 내추럴함과 햇살의 포근한 무드'}
data_A = ({'brand_philosophy': {'manifesto': '버려진 것들에 깃든 빛을 발견합니다. 우리는 무심코 지나치는 폐플라스틱과 조각난 유리에서 햇살 아래 반짝이는 물결의 아름다움을 보았습니다. 숲결은 단순한 리빙 소품을 파는 곳이 아니라, 환경을 지키는 행위가 가장 우아하고 자랑스러운 취향이 될 수 있음을 증명하는 세계입니다.\n당신의 창가에 놓인 작은 오브제 하나가 지구의 짐을 덜어내고, 동시에 당신의 일상을 따스한 온도로 채우길 바랍니다. 지속 가능한 삶은 결코 투박하지 않습니다. 숲결은 가장 세련된 방식으로 내일의 지구를 이야기하며, 당신의 소비가 곧 당신의 고결한 자부심이 되는 세상을 꿈꿉니다.',   'raison_detre': '죄책감 없는 소비를 넘어, 환경을 생각하는 마음이 가장 아름다운 미적 취향이 될 수 있음을 증명하기 위해 존재합니다.',   'stand_against': ['빠르게 소비되고 쉽게 버려지는 패스트 리빙',    '불투명한 소재의 가공 과정과 무분별한 생산',    '심미성이 결여되어 외면받는 투박한 친환경 제품'],   'stand_for': ['쓰임의 가치를 되살리는 영롱한 업사이클링',    '고전적 우아함을 간직한 지속 가능한 미학',    '소재의 여정을 투명하게 공유하는 정직한 신뢰']},  'brand_essence': {'keyword': '영롱한 지속가능성',   'keyword_explanation': '버려진 폐플라스틱과 유리를 햇살을 머금은 물결처럼 영롱하게 재탄생시키며 심미적 가치를 극대화합니다. 이는 단순히 환경 보호를 넘어, 고객이 일상에서 시각적 만족과 윤리적 자부심을 동시에 느끼게 하는 숲결만의 독보적인 가치 구현 방식입니다.',   'brand_definition': '창가에 스며든 햇살과 지속 가능한 마음, 업사이클링 리빙 브랜드 숲결'},  'core_identity': {'mission': '폐자원을 우아한 오브제로 재탄생시켜, 환경을 향한 자부심이 담긴 일상의 온도를 제공한다.',   'vision': '지속 가능한 소재의 아름다움을 정의하는 프리미엄 업사이클링 라이프스타일 큐레이터',   'core_values': [{'value': '투명한 큐레이션',     'description': '소재의 출처와 탄생 과정을 정직하고 전문적으로 공유합니다.',     'example': '제품 패키지에 소재의 수거부터 장인의 손길까지 담은 감성적인 미니 북렛을 반드시 동봉합니다.'},    {'value': '심미적 자부심',     'description': '친환경은 당연하며, 그 결과물은 반드시 가장 아름다워야 한다는 믿음입니다.',     'example': '제품 디자인 시 업사이클링 소재 특유의 질감이 세리프 서체의 고전적 미감과 조화를 이루는지 검토합니다.'},    {'value': '사려 깊은 온도',     'description': '고객의 공간에 따뜻한 위로가 되는 다정한 소통을 지향합니다.',     'example': 'SNS 콘텐츠 작성 시 소재의 가치와 지속 가능한 삶의 방식을 조근조근 설명하는 전문적인 톤앤매너를 유지합니다.'}]}}, {'naming_expansion': {'name_story': "숲결은 '숲의 숨결'과 '햇빛에 비친 물결'이라는 중의적 의미를 담고 있습니다. 무분별하게 버려져 자연을 해치던 소재들이 숲결의 손길을 거쳐, 마치 숲 사이로 부서지는 햇살처럼 투명하고 영롱한 리빙 오브제로 재탄생합니다. 단순히 예쁜 소품을 넘어, 창가에 놓인 소품 하나가 숲의 평온한 결을 집안으로 들여오는 마법 같은 순간을 상징합니다. 자연과 일상이 가장 우아한 방식으로 조우하는 지점을 정의한 이름입니다.",   'domain_suggestions': ['supgyeol.com', 'supgyeol.kr', 'studio-gyeol.co.kr'],   'sns_handles': ['@supgyeol_official', '@gyeol.studio', '@supgyeol.at.home'],   'alternative_names': [{'name': '윤슬결',     'name_en': 'Yunseulgyeol',     'rationale': "'햇빛에 비친 물결'을 뜻하는 순우리말 윤슬을 결합하여, 업사이클링 유리의 영롱한 반짝임이라는 브랜드 시각적 정체성을 더욱 직관적으로 강조할 수 있습니다."},    {'name': '숲의도',     'name_en': 'Supuindo',     'rationale': "숲의 온도와 섬세한 의도(Intent)를 합성한 이름으로, 소재의 가치를 조근조근 설명하는 큐레이터적 페르소나와 '소품의 온도'라는 슬로건을 논리적으로 연결합니다."}]},  'slogan_expansion': {'main_slogan_en': 'The Temperature of Rest, The Texture of Light.',   'sub_slogans': [{'slogan': '지구에서 가장 투명한 쉼을 큐레이션합니다.',     'emphasis': '인스타그램 프로필 및 브랜드 소개 상단용'},    {'slogan': '당신의 창가에 닿은 이 조각은 누군가의 선의와 장인의 고집이 빚어낸 빛입니다.',     'emphasis': '제품과 함께 동봉되는 스토리 북렛 및 언박싱 카드용'},    {'slogan': '사소한 소비가 우아한 자부심이 되는 순간, 숲결의 온도를 경험해 보세요.',     'emphasis': '공식 웹사이트 히어로 섹션 및 메인 배너용'}]},  'brand_story_full': "어느 나른한 오후, 거실 깊숙이 들어온 햇살 속에 먼지가 춤추는 것을 가만히 지켜본 적이 있나요? 우리는 누구나 나만의 공간에서 완벽한 휴식을 꿈꾸지만, 역설적으로 그 공간을 채우기 위해 선택한 수많은 일회용품과 플라스틱들이 우리네 숲과 바다를 숨 가쁘게 만들고 있다는 사실에 때때로 마음이 무거워지곤 합니다. 예쁜 것을 곁에 두고 싶은 욕망과 지구를 아끼고 싶은 마음, 이 두 가지가 충돌할 때 우리는 '지속 가능한 아름다움'에 대한 갈증을 느낍니다.\n\n숲결은 바로 그 지점에서 시작되었습니다. 우리는 버려진 폐플라스틱과 조각난 유리들이 가진 잠재력에 집중했습니다. 쓸모를 다해 버려졌던 소재들이 숲결의 세밀한 공정을 거치면, 마치 보석처럼 빛을 투과하며 공간에 온기를 불어넣는 영롱한 오브제로 거듭납니다. 창가에 놓인 숲결의 소품 하나는 단순한 장식품이 아닙니다. 그것은 햇빛의 결을 붙잡아 당신의 방 안으로 들여보내는 통로이자, 환경을 생각하는 당신의 가치 있는 선택이 틀리지 않았음을 증명하는 우아한 훈장입니다.\n\n숲결은 신뢰감 있는 큐레이터의 시선으로 소재의 여정을 추적하고 장인의 정성을 담아냅니다. 제품을 감싼 포장지를 뜯고 동봉된 미니 북렛을 읽는 순간, 당신은 이 소품이 어떤 과정을 거쳐 당신의 손에 닿았는지 그 숭고한 여정에 동참하게 됩니다. 무분별한 소비가 아닌 가치 있는 소유를 지향하는 삶, 숲결은 당신의 일상이 햇빛에 비친 물결처럼 늘 반짝이기를 바랍니다. 마음이 쉬어가는 소품의 온도, 이제 당신의 창가에서 숲결의 이야기가 시작됩니다."}, {'candidate_1_ethereal_brilliance': {'positioning': {'statement': 'For 미학적 완성도를 중시하는 인테리어 고관여층에게, 숲결은 투박하고 거친 질감의 기존 업사이클링 브랜드와 달리 보석처럼 영롱하게 정제된 ‘투명한 업사이클링 오브제’를 제공합니다.',    'differentiators': [{'point': "폐플라스틱의 미학적 환생, 'Glassy Texture'",      'description': '재생 소재라고 믿기 힘든 투명함과 빛의 굴절을 극대화한 가공 기술을 통해, 쓰레기를 보석의 지위로 격상시킨 하이엔드 퀄리티를 구현합니다.'},     {'point': '햇살을 가두는 ‘세리프 디테일’ 디자인',      'description': '우아한 명조체의 선율을 닮은 비정형적이고 섬세한 디자인 곡선을 통해, 단순한 소품을 넘어 창가에 두는 것만으로 공간의 품격을 높이는 예술적 가치를 제공합니다.'},     {'point': '무구한 투명함이 주는 시각적 휴식',      'description': '복잡한 색상을 배제하고 소재 본연의 맑음을 강조하여, 시각적 노이즈를 줄이고 사용자에게 ‘물결을 바라보는 듯한’ 깊은 평온함을 선사합니다.'}],    'positioning_map_visualized': {'axis_x': '소재의 가시성 (거친 재활용 흔적 ↔ 정제된 예술적 완성도)',     'axis_y': '브랜드 지향점 (실용적 기능 중심 ↔ 심미적 오브제 중심)',     'quadrants_description': '1사분면은 예술적 가치를 지닌 업사이클링, 2사분면은 실용적인 리사이클 소품, 3사분면은 저가형 대량 생산 제품, 4사분면은 심미적이지만 환경 가치가 배제된 럭셔리 소품 시장입니다.',     'our_exact_position': "숲결은 1사분면의 최상단에 위치하며, '지속 가능한 럭셔리 오브제'라는 독보적인 분위기를 선점하여 기존 에코 브랜드의 한계를 넘어섭니다."}},   'unbreakable_brand_promise': {'declaration': '우리는 당신에게 항상 [일상의 가장 아름다운 반짝임]을 드립니다.',    'proof_of_promise': [{'channel': '마케팅 콘텐츠',      'actionable_rule': '모든 이미지는 자연광 아래에서 촬영하며, 보정 시 인위적인 필터 대신 소재의 투명도와 굴절률을 강조하는 고해상도 접사 컷을 사용한다.'},     {'channel': '패키징 및 언박싱',      'actionable_rule': '포장재는 빛이 투과되는 생분해성 트레이싱지를 사용하여 제품을 꺼내기 전부터 숲결 특유의 영롱한 무드를 예고한다.'},     {'channel': '고객 응대 (CS)',      'actionable_rule': "제품의 마모나 손상 문의 시, '수선'이 아닌 '재연마(Polishing)' 서비스를 제안하여 제품이 지닌 보석으로서의 가치를 끝까지 유지시킨다."}]}},  'candidate_2_warm_sanctuary': {'positioning': {'statement': 'For 지친 일상 속 정서적 회복이 필요한 1인 가구에게, 숲결은 기능에만 치중한 차가운 생활용품들과 달리 햇살의 온기를 담은 리넨 색감의 ‘심리적 온도 조절 소품’을 제공합니다.',    'differentiators': [{'point': '마음을 데우는 #F5E6D3의 색채 심리학',      'description': '차가운 플라스틱의 느낌을 완벽히 지운 따스한 리넨 베이지 톤을 적용하여, 제품이 공간에 놓이는 순간 시각적 온도를 2도 높이는 심리적 안도감을 제공합니다.'},     {'point': '조근조근 들려주는 ‘소재의 온도’ 큐레이션',      'description': '단순한 판매가 아닌, 소재가 거쳐온 시간과 그것이 사용자에게 줄 수 있는 정서적 위안을 전문 큐레이터의 목소리로 전달하여 제품과의 정서적 유대를 형성합니다.'},     {'point': '창가 최적화(Window-side) 디자인',      'description': "햇빛과 만났을 때 가장 아름다운 그림자를 만드는 구조적 설계를 통해, 하루 중 가장 평화로운 '창가에서의 휴식 시간'을 브랜드 경험으로 점유합니다."}],    'positioning_map_visualized': {'axis_x': '브랜드 톤앤매너 (차가운 현대미 ↔ 따뜻한 고전미)',     'axis_y': '고객 경험 가치 (편의성 중심 ↔ 정서적 교감 중심)',     'quadrants_description': '1사분면은 정서적 교감의 고전미, 2사분면은 트렌디한 편의성, 3사분면은 가성비 중심 실용성, 4사분면은 프리미엄 미니멀리즘 시장입니다.',     'our_exact_position': "숲결은 1사분면의 중심에 위치하여, '가장 따뜻하고 클래식한 휴식의 도구'로서 정서적 고립감을 느끼는 현대인들에게 안식처 같은 분위기를 선사합니다."}},   'unbreakable_brand_promise': {'declaration': '우리는 당신에게 항상 [마음이 쉬어가는 소품의 온도]를 드립니다.',    'proof_of_promise': [{'channel': '마케팅 콘텐츠',      'actionable_rule': "SNS 포스팅 시 정보 전달보다는 '오늘의 햇살 기록'과 같은 감성적인 에세이 형식을 취하며, 신뢰감 있는 차분한 어조의 문체만 사용한다."},     {'channel': '패키징 및 언박싱',      'actionable_rule': '상자를 열었을 때 은은한 숲의 향기가 나도록 천연 아로마 패치를 동봉하여, 시각을 넘어 후각적으로도 즉각적인 휴식 경험을 제공한다.'},     {'channel': '고객 응대 (CS)',      'actionable_rule': "모든 상담의 끝에는 사용자의 평안한 하루를 기원하는 '숲결의 온도 문장'을 고객의 이름과 함께 적어 인간적인 유대감을 완성한다."}]}},  'candidate_3_ethical_intellectual': {'positioning': {'statement': 'For 자신의 소비가 세상에 미치는 영향을 고민하는 의식 있는 소비자에게, 숲결은 그린워싱에 불과한 모호한 친환경 브랜드와 달리 소재의 전 여정을 투명하게 공개하는 ‘지속 가능한 자부심의 기록’을 제공합니다.',    'differentiators': [{'point': "데이터 기반의 'Material Journey' 증명",      'description': '폐유리가 소품으로 탄생하기까지의 탄소 저감 수치와 공정 과정을 미니 북렛으로 제공하여, 단순한 소비를 가치 있는 투자로 전환시킵니다.'},     {'point': '장인 정신과 업사이클링의 결합',      'description': '버려진 소재를 다루는 로컬 장인과의 협업 과정을 상세히 기록하여, 제품의 희소성과 더불어 지역 사회 선순환에 기여한다는 실질적인 자부심을 부여합니다.'},     {'point': '지속 가능한 삶을 위한 ‘전문적 가이드’',      'description': '제품 사용법을 넘어, 해당 소재를 오래 보존하고 폐기 시 재순환하는 방법까지 전문적으로 큐레이션하여 고객의 라이프스타일 전반을 리드합니다.'}],    'positioning_map_visualized': {'axis_x': '커뮤니케이션 방식 (이미지 중심 ↔ 서사/정보 중심)',     'axis_y': '소비의 목적 (자기 과시 ↔ 자기 가치 실현)',     'quadrants_description': '1사분면은 정보 기반의 가치 실현, 2사분면은 이미지 기반의 자기 과시, 3사분면은 단순 필요에 의한 소비, 4사분면은 전통적 가치 소비 시장입니다.',     'our_exact_position': "숲결은 1사분면의 끝단에 위치하여, '가장 지적이고 투명한 친환경 브랜드'로서 고객이 스스로의 소비를 자랑스러워할 수 있는 확실한 논리를 제공합니다."}},   'unbreakable_brand_promise': {'declaration': '우리는 당신에게 항상 [소비 그 이상의 환경적 자부심]을 드립니다.',    'proof_of_promise': [{'channel': '마케팅 콘텐츠',      'actionable_rule': "제품의 장점보다 소재의 수거 출처와 제작 공정의 어려움을 가감 없이 공개하는 'Raw Report'를 정기적으로 발행하여 신뢰도를 구축한다."},     {'channel': '패키징 및 언박싱',      'actionable_rule': "제품별 고유 일련번호와 제작에 참여한 장인의 서명이 담긴 미니 북렛을 동봉하여, 이 제품이 '유일무이한 가치'를 지녔음을 물리적으로 증명한다."},     {'channel': '고객 응대 (CS)',      'actionable_rule': "제품 파손 시 단순히 새 제품 교환이 아닌, 파손된 제품을 수거하여 다시 재활용 공정으로 돌려보내는 '순환형 보상 판매'를 원칙으로 한다."}]}}})
data_B = ({'strategic_reasoning': "브랜드 '숲결'의 '지속 가능한 소재의 아름다움'과 고객 인터뷰에서 도출된 '일회용품에 대한 부채감'을 결합할 때, 가장 강력한 구매 전환은 자신의 공간을 도덕적·심미적 완결 상태로 만들고자 하는 '의식 있는 도시 생활자'에게서 발생합니다. 이들은 단순히 예쁜 소품이 아니라, 일상에서 느끼는 환경적 죄책감을 해소해주고 자신의 정체성을 긍정하게 만드는 '정서적 세탁' 기제를 구매하는 것이기에 전환율이 극대화됩니다.",  'core_target_group': {'definition': '환경적 부채감을 미학적 성취감으로 대체하고자 하는 도시형 컨셔스 테이스트 메이커',   'demographics': '28-36세 여성 및 남성, 화이트칼라 전문직 또는 크리에이티브 직군, 도심 거주 1인 가구 및 신혼부부',   'lifestyle_keywords': ['제로웨이스트', '미니멀라이프', '슬로우라이프', '지속가능한인테리어', '컨셔스소비'],   'consumption_behavior': "배달 음식이나 저가형 패스트 리빙 제품에는 철저히 가성비를 따지지만, 매일 손에 닿고 시선이 머무는 '반영구적 리빙 오브제'에는 10만 원 이상의 가심비를 기꺼이 지불함"},  'primary_persona': {'name': '김지안',   'age_and_job': '31세, IT 기업 서비스 기획자',   'daily_scene': '고강도 업무 후 퇴근하여 문을 열었을 때, 현관에 쌓인 택배 박스와 배달 용기들을 보며 삶이 소모되고 있다는 느낌을 받는 순간',   'pain_point_and_desire': "세련된 사회적 모습과 달리 일회용품으로 점철된 사적 공간에서의 괴리감. 숲결의 소품을 통해 자신의 일상을 다시 '정갈하고 가치 있는 상태'로 회복하고 싶어 함",   'emotional_needs': ['죄책감 없는 휴식',    '윤리적 소비를 통한 자아 효능감',    '자연에 가까운 질감이 주는 정서적 안정'],   'deal_breaker': '친환경을 표방하면서도 패키징에 비닐 에어캡을 과도하게 사용하거나, 소재의 출처가 불분명한 제품'},  'secondary_personas': [{'id': 1,    'name_and_demographic': '박서준 (34세, 건축가)',    'character_type': '심미적 미니멀리스트',    'why_they_buy': "소재 자체가 주는 본연의 아름다움을 중시하며, 불필요한 장식이 배제된 '숲결'의 정갈한 디자인을 공간의 마침표로 활용하기 위해 구매"},   {'id': 2,    'name_and_demographic': '이지혜 (29세, 프리랜서 디자이너)',    'character_type': '트렌드 추종형 가치 소비자',    'why_they_buy': "인플루언서의 피드에서 본 '숲결'의 이미지를 보고, 자신의 SNS에 '의식 있는 라이프스타일'을 전시하기 위한 인증 수단으로 구매"},   {'id': 3,    'name_and_demographic': '최민정 (33세, 공무원)',    'character_type': '의미 부여형 선물 탐색자',    'why_they_buy': "집들이나 생일 선물 시 '흔하지 않으면서도 주는 사람의 격조와 받는 사람의 가치관을 동시에 챙길 수 있는' 최적의 선택지로 인식"},   {'id': 4,    'name_and_demographic': '한도윤 (35세, 신혼부부)',    'character_type': '지속 가능한 삶의 시작가',    'why_they_buy': "결혼 후 '오래 쓸 수 있는 좋은 것'들로 집안을 채우기로 결심하며, 플라스틱 대안품으로서 숲결의 제품군을 세트로 구비"}],  'emotional_triggers': [{'trigger': '부채감의 해소 (Ethical Cleansing)',    'reason': '플라스틱에 둘러싸인 일상에서 오는 무의식적 죄책감을 숲결의 소재가 주는 깨끗함과 온도로 정화해준다는 점을 강조'},   {'trigger': "지적 허영심이 아닌 '의식의 자부심'",    'reason': "남들에게 보여주기 위한 소비를 넘어, 스스로가 환경을 생각하는 '좋은 사람'이라는 확신을 주는 브랜딩을 통해 결제 정당성 부여"},   {'trigger': '감각적 위로 (Tactile Comfort)',    'reason': '차가운 스마트폰과 키보드만 만지는 타겟에게 나무, 돌, 린넨 등 자연 소재의 온도가 주는 휴식의 실체를 구체적인 카피로 자극'}]}, {'strategic_reasoning': "지속 가능한 소품이라는 고관여 감성 업종 특성상, 논리적 설득보다는 '가치 공유'와 '시각적 선망성'이 구매 결정의 핵심입니다. 타겟이 배달 음식 등에서 느끼는 '환경 부채감'을 해소해주는 '심리적 보상'을 구매 여정 곳곳에 배치하였으며, 제품의 교체 주기나 인테리어 권태기가 찾아오는 45일 지점을 재구매 유도 타이밍으로 설정했습니다.",  'customer_journey_map': [{'stage': '1. 인지 (Awareness)',    'touchpoint': '인스타그램 및 핀터레스트 (지속 가능성/미니멀리즘 인플루언서 협업)',    'customer_emotion': '"매일 플라스틱만 버리는 내 방이랑은 너무 다르네... 저런 정갈한 삶은 어디서 오는 걸까?"',    'brand_action': "소품의 기능을 강조하기보다 '죄책감 없는 휴식'을 시각화한 고감도 릴스 및 이미지 피드 송출"},   {'stage': '2. 탐색 (Consideration)',    'touchpoint': '자사몰 상세페이지 및 네이버 블로그 검색',    'customer_emotion': '"디자인은 예쁜데, 진짜 친환경 소재가 맞을까? 괜히 예쁜 쓰레기를 사는 건 아닐까?"',    'brand_action': "상세페이지 최상단에 소재 가공 과정과 탄소 배출 저감 수치를 데이터로 시각화하고 '100% 분해되는 패키지' 영상 배치"},   {'stage': '3. 구매 (Purchase)',    'touchpoint': '장바구니 및 결제 페이지',    'customer_emotion': '"배송 오다가 깨지면 어떡하지? 종이 포장이라는데 안전하게 올까?"',    'brand_action': "결제 버튼 직전에 '파손 시 100% 무상 교환 보장' 문구와 '플라스틱 프리 포장 완료 사진' 실시간 리뷰 연동"},   {'stage': '4. 재구매 (Retention)',    'touchpoint': '카카오 알림톡 (첫 구매 후 45일 시점)',    'customer_emotion': '"한 달 정도 써보니 집안 분위기가 확실히 달라졌어. 다른 방에도 이런 온도가 필요해."',    'brand_action': "제품 관리 팁이 담긴 '마음 관리 레터' 발송 및 기존 구매 제품과 레이어드하기 좋은 소품 추천 '멤버십 전용 15% 시크릿 링크' 제공"},   {'stage': '5. 팬화 (Advocacy)',    'touchpoint': '인스타그램 스토리 및 실사용자 커뮤니티',    'customer_emotion': '"이 제품을 쓰는 내 모습이 너무 마음에 들어. 내가 이렇게 의식 있는 사람이라는 걸 보여주고 싶어."',    'brand_action': "언박싱 시 제품 뒤에 배치하면 화보가 되는 '숲결 무드 카드'와 인스타 태그 시 다음 달 '이달의 숲결지기' 선정 및 신제품 프리뷰 기회 부여"}]})
data_C = {'color_palette': [{'color_name': '심연의 숲',   'hex_code': '#2C332B',   'role': 'Text Color',   'reason': '단단하고 정직한 브랜드의 목소리를 대변하며 가독성을 확보하는 깊은 먹색'},  {'color_name': '새벽녘 모래',   'hex_code': '#F5E6D3',   'role': 'Primary',   'reason': '사용자 선택 시드 컬러로, 마음이 쉬어가는 따뜻한 소품의 온도를 상징함'},  {'color_name': '안개 낀 잎새',   'hex_code': '#9BA89B',   'role': 'Secondary',   'reason': '몽환적인 새벽 숲의 분위기를 자아내며 메인 컬러와 차분한 조화를 이룸'},  {'color_name': '마른 나무줄기',   'hex_code': '#8C7B6C',   'role': 'Accent',   'reason': '지속 가능한 소재의 견고함과 자연의 생명력을 강조하기 위한 포인트 컬러'},  {'color_name': '안식의 여백',   'hex_code': '#F9F6F2',   'role': 'Background',   'reason': '시드 컬러보다 밝은 톤으로, 공간감을 확장하고 시각적 피로도를 낮춤'}], 'typography': {'primary_font': {'category': '헤드라인 및 타이틀',   'font_name_kr': '고딕 A1',   'google_fonts_family': 'Gothic A1',   'weight_recommendation': 800,   'usage_and_reason': '획이 굵고 정직한 직선 위주의 서체로, 브랜드의 단단한 철학과 자부심을 시각적으로 전달함'},  'secondary_font': {'category': '본문 및 일반 텍스트',   'font_name_kr': '본고딕',   'google_fonts_family': 'Noto Sans KR',   'weight_recommendation': 400,   'usage_and_reason': '정보 전달의 명확성을 위해 장식성을 배제하고 현대적인 가독성을 극대화함'}}, 'visual_mood_guide': {'photography_do': ['조명 온도를 5000K 이상의 쿨톤으로 설정하고 가습기나 포그 머신을 활용해 미세한 공기감을 연출할 것',   '피사체를 중앙에서 벗어나게 배치하여 여백의 미를 강조하고 자연스러운 시선의 흐름을 유도할 것',   '소재의 질감이 드러나도록 측면에서 들어오는 부드러운 확산광(Diffused Light)을 사용할 것'],  'photography_dont': ['직사광선에 의한 강한 그림자나 인위적인 하이라이트 표현 금지',   '채도가 높은 원색 소품이나 플라스틱 재질의 배경지 사용 금지',   '과도한 광각 렌즈 사용으로 인한 사물의 형태 왜곡 금지'],  'mood_keywords': ['정적인', '정직한', '몽환적인', '유연한', '지속가능한']}, 'design_principles': {'layout_direction': '정형화된 그리드에서 벗어나 유기적인 곡선형 레이아웃을 사용하며, 요소 간 간격을 넓게 유지해 숲길의 여유로운 공간감을 구현합니다. 버튼이나 카드 UI의 모서리는 비정형적인 라운드 값을 적용해 자연물의 형태를 모방합니다.',  'image_processing': '이미지 전체의 채도를 15-20% 낮추고 대비를 완만하게 조절하여 안개 낀 듯한 몽환적인 톤을 유지합니다. 텍스처는 매끄러운 광택보다는 종이나 나무의 거친 질감이 미세하게 느껴지도록 노이즈 값을 소량 추가합니다.'}}
data_DE = {'logo_identity': {'concept': {'symbol_reason': "숲속 연못에 떨어진 한 방울의 물이 만드는 잔잔한 동심원을 모티프로 선정했습니다. 이는 소품 하나가 공간 전체로 퍼뜨리는 평온한 에너지와 지속 가능한 가치의 선순환을 상징하며, 숲결이 추구하는 '마음의 휴식'을 시각적 파동으로 형상화한 것입니다.", 'color_reason': '심연의 숲(#2C332B)은 브랜드의 단단한 철학을 지탱하며, 새벽녘 모래(#F5E6D3)와 안개 낀 잎새(#9BA89B)의 조합은 업사이클링 소재 특유의 영롱함과 숲의 서늘하면서도 따뜻한 온도를 동시에 전달하여 고객에게 정서적 안정을 제공합니다.', 'overall_message': "첫째, 본 로고는 정형화된 원형을 넘어 서예의 필치가 가미된 유기적 선을 통해 인위적이지 않은 자연의 미학을 드러냅니다. 이는 '나만의 취향'을 찾는 고객에게 브랜드가 가진 고유한 결을 직관적으로 전달하는 장치입니다.\n\n둘째, 극도의 여백과 절제된 라인의 배합은 번잡한 일상에서 벗어난 안식처로서의 브랜드 아이덴티티를 확립합니다. 차분한 톤의 컬러 팔레트는 시각적 피로도를 낮추고 고급스러운 리빙 브랜드로서의 권위를 부여합니다.\n\n셋째, 최종적으로 고객은 이 로고를 통해 단순한 소비를 넘어 자아를 회복하는 명상적 경험을 마주하게 됩니다. 섬세한 세리프 타이포그래피와 결합된 심볼은 숲결의 제품이 단순한 물건이 아닌, 삶의 질서를 세우는 오브제임을 각인시킵니다.", 'direction_text': "A minimalist vector logo featuring a single, refined concentric circle ripple on a clean field. The lines should have the subtle thickness variation of a modern calligraphy brush, flowing organically like liquid. No gradients or 3D effects. The typography '숲결' is placed with generous letter-spacing below the symbol in an elegant, high-contrast serif font. High negative space, monochromatic deep forest green (#2C332B) on a warm sand background (#F5E6D3)."}, 'guide': {'minimum_size': 'Print: 15mm (Width) / Digital: 48px (Width) - 가독성 확보를 위한 최소 규정', 'clear_space': '심볼의 높이를 X라고 할 때, 사방으로 X의 1/2 이상의 여백을 반드시 확보해야 함'}}, 'character_guide': {'intro': {'name': '시울 (Si-ul)', 'appearance': '안개를 닮은 은은한 회색빛 깃털을 가진 학. 길고 유연한 목선과 정갈하게 정돈된 부리를 가졌으며, 발치에는 투명하게 빛나는 업사이클링 유리 구슬을 조심스럽게 굴리고 있는 형태.', 'symbolic_value': '정적인 지혜, 고귀한 회복, 지속 가능한 아름다움'}, 'reasoning': {'selection_reason': "학은 예로부터 선비의 곁을 지키는 고고함과 장수를 상징하는 영물입니다. 이는 유행에 휩쓸리지 않는 '취향의 차별화'를 원하는 타겟 고객의 지향점과 일치하며, 폐기물을 영롱한 가치로 되살리는 업사이클링의 영속성을 투영하기에 가장 적합한 모티프입니다.", 'emotional_connection': '사회적 가면을 벗고 홀로 남은 시간, 고객은 시울의 고요한 몸짓에서 위안을 얻습니다. 학이 머무는 자리가 곧 청정한 숲이 되듯, 시울은 고객의 개인적 공간을 신성한 안식처로 격상시키는 심리적 마스코트 역할을 수행합니다.'}, 'story': {'background': '안개 낀 새벽 숲, 버려진 조각들을 모아 맑은 연못물에 씻어내어 반짝이는 보석으로 만드는 은둔의 큐레이터입니다.', 'brand_role': "제품의 소재가 거쳐온 여정을 설명하고, 고객에게 '지속 가능한 삶의 방식'을 조근조근 안내하는 전문적인 큐레이터이자 명상 가이드입니다."}}, 'logo_path': 'c:\\Users\\joyos\\workspace\\Name_Tag_Test_Repository\\assets\\logos\\logo_숲결_20260529_135931.png', 'char_path': 'c:\\Users\\joyos\\workspace\\Name_Tag_Test_Repository\\assets\\characters\\char_숲결_20260529_140548.png'}

# %%
# 2. HTML 엔진 가동 (모듈 조립)
print("⚙️ NameTag 메인 엔진 조립 중...")
final_html_content = assemble_html(brand_info, data_A, data_B, data_C, data_DE)

# 3. WeasyPrint를 통한 고해상도 PDF 구워내기
output_filename = "nametag_brand_guideline.pdf"

print("🖨️ PDF 렌더링 중... (최초 실행 시 구글 폰트 다운로드로 몇 초 걸릴 수 있습니다)")
# WeasyPrint로 HTML 문자열을 읽어 PDF 파일로 저장
HTML(string=final_html_content).write_pdf(output_filename)
# Out:
# ⚙️ NameTag 메인 엔진 조립 중...
# 🖨️ PDF 렌더링 중... (최초 실행 시 구글 폰트 다운로드로 몇 초 걸릴 수 있습니다)
